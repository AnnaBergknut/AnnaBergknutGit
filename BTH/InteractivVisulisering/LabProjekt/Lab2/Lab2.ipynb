# %% [markdown]
# # Lab 2
# 1. what relationship between happiness score and the gdp?
# **h1: it has a directly propotinal relationship. -
# yes they had is acording to the gafs**
#
#
# **h0: they don't have a directly realaationship**
#
#
# 2. dose money make you happy?
# **h1: yes, there is a big diffrense. - yes **
#
#
# **h0: no, there is no big diffrence bwtweeen them.**

# %%
# %matplotlib inline
import matplotlib.pyplot as mpl

import pandas as pd
import numpy  as np
import scipy.stats as scp

# %%
happydf = pd.read_csv("2019.csv", sep=",")
happydf
# Out:
#      Overall_rank         Country_or_region  Score  GDP_per_capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social_support  Healthy_life_expectancy  Freedom_to_make_life_choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
happydf.head(20)
# Out:
#     Overall_rank Country_or_region  Score  GDP_per_capita  Social_support  \
# 0              1           Finland  7.769           1.340           1.587
# 1              2           Denmark  7.600           1.383           1.573
# 2              3            Norway  7.554           1.488           1.582
# 3              4           Iceland  7.494           1.380           1.624
# 4              5       Netherlands  7.488           1.396           1.522
# 5              6       Switzerland  7.480           1.452           1.526
# 6              7            Sweden  7.343           1.387           1.487
# 7              8       New Zealand  7.307           1.303           1.557
# 8              9            Canada  7.278           1.365           1.505
# 9             10           Austria  7.246           1.376           1.475
# 10            11         Australia  7.228           1.372           1.548
# 11            12        Costa Rica  7.167           1.034           1.441
# ...

# %%
happydf.shape #vissar som en tupel
# Out:
# (156, 9)

# %%
happydf.isnull().values.any() #om ture bytt data
# Out:
# False

# %%
x = happydf.Country_or_region
y = happydf.Score

fig = mpl.figure(figsize = (14,50))
ax = fig.add_subplot()

ax.scatter(y,x)
ax.grid()
ax.set_xlim(2,8)
ax.set_ylim(-1,156)
ax.set_ylabel('Country')
ax.set_xlabel('Score')
ax.set_title('County o Score')
# Out:
# Text(0.5, 1.0, 'County o Score')

# %%
x = happydf.Score

fig = mpl.figure(figsize = (14,7))
ax = fig.add_subplot()

ax.grid()
ax.boxplot(x)
ax.set_ylim(2,9)
ax.set_xlabel('Distrubution')
ax.set_ylabel('Score')
ax.set_title('Distrubution of happiness')
# Out:
# Text(0.5, 1.0, 'Distrubution of happiness')

# %%
x = happydf.Score

fig = mpl.figure(figsize = (14,7))
ax = fig.add_subplot()
ax.grid()

ax.set_xticks(np.arange(2.5,8.0,0.5))
ax.hist(x, 10, rwidth =0.5)
# Out:
# (array([ 5.,  8., 10., 31., 21., 21., 28., 11., 12.,  9.]),
#  array([2.853 , 3.3446, 3.8362, 4.3278, 4.8194, 5.311 , 5.8026, 6.2942,
#         6.7858, 7.2774, 7.769 ]),
#  <BarContainer object of 10 artists>)

# %%
x = happydf.GDP_per_capita
y = happydf.Score

fig = mpl.figure(figsize = (14,7))
ax = fig.add_subplot()
ax.grid()

ax.set_xlabel("GDP")
ax.set_ylabel("Score")
ax.set_title("GDP vs Score")

ax.scatter(x,y)

# %%
data_linreg = np.polyfit(happydf.GDP_per_capita, happydf.Score, 1)
print(data_linreg)
# Out:
# [2.218148   3.39934518]

# %%
x = happydf.GDP_per_capita
y = happydf.Score

xp = np.linspace(-0.02, 1.75, 156)
lr = np.polyval(data_linreg, xp)

fig = mpl.figure(figsize = (14,7))
ax = fig.add_subplot()
ax.grid()

ax.set_xlabel("GDP")
ax.set_ylabel("Score")
ax.set_title("GDP vs Score")

ax.scatter(x,y, color = "lightgrey")
ax.plot(xp, lr, color = "blue")

# %%
x = happydf.Healthy_life_expectancy
y = happydf.Score

fig = mpl.figure(figsize = (14,7))
ax = fig.add_subplot()
ax.grid()

ax.set_xlabel("Healthy_life_expectancy")
ax.set_ylabel("Score")
ax.set_title("Life expecensy vs Score")

ax.scatter(x,y)

# %%
data_polreg = np.polyfit(happydf.Healthy_life_expectancy, happydf.Score, 2)
print(data_polreg)
# Out:
# [ 3.14015622 -0.50866522  3.94143987]

# %%
x = happydf.Healthy_life_expectancy
y = happydf.Score

xp = np.linspace(-0.02, 1.2, 156)
pr = np.polyval(data_polreg, xp)

fig = mpl.figure(figsize = (14,7))
ax = fig.add_subplot()
ax.grid()

ax.set_xlabel("Healthy life")
ax.set_ylabel("Score")
ax.set_title("Healthy life expectancy vs Score")

ax.scatter(x,y, color = "lightgrey")
ax.plot(xp, pr, color = "red")

# %%
rel_happy_life = scp.pearsonr(happydf.Score, happydf.Healthy_life_expectancy)
rel_happy_gdp = scp.pearsonr(happydf.Score, happydf.GDP_per_capita)

print(rel_happy_life)
print(rel_happy_gdp)
# Out:
# PearsonRResult(statistic=0.7798831492425831, pvalue=3.785454064840088e-33)
# PearsonRResult(statistic=0.7938828678781279, pvalue=4.3154809133189535e-35)

# %%
x= np.linspace(0,156, 156)
y = happydf.Score

fig = mpl.figure(figsize = (18,50))
ax = fig.add_subplot()
ax.grid()

ax.set_xlabel("Country rank")
ax.set_ylabel("Score")
ax.set_title("Healthy life expectancy vs Score")

#ax.set_yticks()

ax.scatter(x,y)
#ax.plot(xp, pr, color = "green")

# %%
happy_lowdf=happydf[happydf['Score']<4.3]
happy_lowdf
# Out:
#      Overall_rank         Country_or_region  Score  GDP_per_capita  \
# 133           134                  Ethiopia  4.286           0.336
# 134           135                 Swaziland  4.212           0.811
# 135           136                    Uganda  4.189           0.332
# 136           137                     Egypt  4.166           0.913
# 137           138                    Zambia  4.107           0.578
# 138           139                      Togo  4.085           0.275
# 139           140                     India  4.015           0.755
# 140           141                   Liberia  3.975           0.073
# 141           142                   Comoros  3.973           0.274
# 142           143                Madagascar  3.933           0.274
# 143           144                   Lesotho  3.802           0.489
# 144           145                   Burundi  3.775           0.046
# 145           146                  Zimbabwe  3.663           0.366
# ...

# %%
happy_highdf = happydf[happydf['Score']>= 6.5]
happy_highdf
# Out:
#     Overall_rank     Country_or_region  Score  GDP_per_capita  Social_support  \
# 0              1               Finland  7.769           1.340           1.587
# 1              2               Denmark  7.600           1.383           1.573
# 2              3                Norway  7.554           1.488           1.582
# 3              4               Iceland  7.494           1.380           1.624
# 4              5           Netherlands  7.488           1.396           1.522
# 5              6           Switzerland  7.480           1.452           1.526
# 6              7                Sweden  7.343           1.387           1.487
# 7              8           New Zealand  7.307           1.303           1.557
# 8              9                Canada  7.278           1.365           1.505
# 9             10               Austria  7.246           1.376           1.475
# 10            11             Australia  7.228           1.372           1.548
# ...

# %%
tempavg = happydf[happydf['Score']>=4.3]
happy_avgdf = tempavg[tempavg['Score']<6.5]
happy_avgdf
# Out:
#      Overall_rank Country_or_region  Score  GDP_per_capita  Social_support  \
# 24             25            Taiwan  6.446           1.368           1.430
# 25             26             Chile  6.444           1.159           1.369
# 26             27         Guatemala  6.436           0.800           1.269
# 27             28      Saudi Arabia  6.375           1.403           1.357
# 28             29             Qatar  6.374           1.684           1.313
# ..            ...               ...    ...             ...             ...
# 128           129      Sierra Leone  4.374           0.268           0.841
# 129           130         Sri Lanka  4.366           0.949           1.265
# 130           131           Myanmar  4.360           0.710           1.181
# 131           132              Chad  4.350           0.350           0.766
# 132           133           Ukraine  4.332           0.820           1.390
#
# ...

# %%
vartest_low = np.poly1d(happy_lowdf.Score)
vartest_avg = np.poly1d(happy_avgdf.Score)
vartest_high = np.poly1d(happy_highdf.Score)

stat, p = scp.levene(vartest_low, vartest_avg, vartest_high)
print('l-statistics = ', stat)
print('p value =', p)

alpha = 0.05
if p>alpha:
    print('same variance')
else:
    print('diff variance')
# Out:
# l-statistics =  13.43875083106697
# p value = 4.279566491406237e-06
# diff variance

# %%
krus, p = scp.kruskal(vartest_low, vartest_avg, vartest_high)


print('k-statistics = ', krus)
print('p value =', p)

alpha = 0.05
if p>alpha:
    print('no big diffrence between variables')
else:
    print('big diff')
# Out:
# k-statistics =  101.06973347937198
# p value = 1.1297600964782507e-22
# big diff
