# %% [markdown]
# # Video Game Sales
# ### Group9: Anna Bergknut, Jeff Andersson, Sebastian Johansson

# %%
# %matplotlib inline
import matplotlib.pyplot as mpl

import pandas as pd
import numpy  as np
import scipy.stats as scp

# %%
dataset = pd.read_csv("vgsales.csv", sep=",")
dataset
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
x = dataset.Year
y = dataset.Global_Sales

fig = mpl.figure(figsize = (15,15))
ax = fig.add_subplot()
ax.grid()

ax.set_xlabel("Year")
ax.set_ylabel("Sale")
ax.set_title("Global sales per year")

ax.scatter(x,y)

# %%
y = dataset.Year
a = dataset.Global_Sales
x = dataset.Genre

fig = mpl.figure(figsize = (15,15))
ax = fig.add_subplot()
ax.grid()

ax.set_xlabel("Genre")
ax.set_ylabel("Year")
ax.set_title("what genre is popular per year")

# ax.bar(x,y)

ax.set_xticks(np.arange(1,12,1))
ax.hist(x, 12, rwidth =0.5)
# Out:
# (array([2346.,  886., 1249., 1488.,  582., 1739., 1310.,  867., 3316.,
#          848., 1286.,  681.]),
#  array([ 0.        ,  0.91666667,  1.83333333,  2.75      ,  3.66666667,
#          4.58333333,  5.5       ,  6.41666667,  7.33333333,  8.25      ,
#          9.16666667, 10.08333333, 11.        ]),
#  <BarContainer object of 12 artists>)

# %%
data_polreg = np.polyfit(dataset.Year, dataset.Global_Sales, 2)
print(data_polreg)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8200\1900016479.py in <module>
# ----> 1 data_polreg = np.polyfit(dataset.Year, dataset.Global_Sales, 2)
#       2 print(data_polreg)
#
# <__array_function__ internals> in polyfit(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     658     scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     659     lhs /= scale
# --> 660     c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     661     c = (c.T/scale).T  # broadcast scale coefficients
#     662
#
# <__array_function__ internals> in lstsq(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py in lstsq(a, b, rcond)
#    2304         # lapack can't handle n_rhs = 0 - so allocate the array one larger in that axis
# ...

# %%
x = dataset.Year
y = dataset.Global_Sales
shooter = dataset[dataset['Genre'] == 'Shooter']

# xp = np.linspace(1980, 2016, 10000)
# pr = np.polyval(data_polreg, xp)

fig = mpl.figure(figsize = (15,15))
ax = fig.add_subplot()
ax.grid()

ax.set_xlabel("Year")
ax.set_ylabel("Sale")
ax.set_title("rise and fall of shooter games global")

ax.scatter(shooter.Year,shooter.Global_Sales)

# ax.plot(xp, pr, color = "red")

# %%
market = ("NA", "EU", "JP", "WORLD")
x = dataset.Year
Y = dataset.Platform

fig = mpl.figure(figsize = (15,15)
ax = fig.add_subplot()
ax.grid()

ax.set_xticks(np.arange(1,12,1))
ax.hist(x, 12, rwidth =0.5)
                 
# x = np.arange(len(market))  # the label locations
# width = 0.25  # the width of the bars
# multiplier = 0

# fig, ax = plt.subplots(constrained_layout=True)

# for attribute, measurement in penguin_means.items():
#     offset = width * multiplier
#     rects = ax.bar(x + offset, measurement, width, label=attribute)
#     ax.bar_label(rects, padding=3)
#     multiplier += 1

# # Add some text for labels, title and custom x-axis tick labels, etc.
# ax.set_ylabel('Length (mm)')
# ax.set_title('Penguin attributes by species')
# ax.set_xticks(x + width, species)
# ax.legend(loc='upper left', ncols=3)
# ax.set_ylim(0, 250)

# plt.show()
# Out:
#   File "C:\Users\annan\AppData\Local\Temp\ipykernel_9620\2271991564.py", line 6
#     ax = fig.add_subplot()
#     ^
# SyntaxError: invalid syntax
