# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\annan\repos\AnnaBergknutGit\BTH\TillämpadAI\Task4.ipynb Cell 1 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/annan/repos/AnnaBergknutGit/BTH/Till%C3%A4mpadAI/Task4.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/c%3A/Users/annan/repos/AnnaBergknutGit/BTH/Till%C3%A4mpadAI/Task4.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np
# ----> <a href='vscode-notebook-cell:/c%3A/Users/annan/repos/AnnaBergknutGit/BTH/Till%C3%A4mpadAI/Task4.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> from sklearn.metrics import mean_squared_error
#       <a href='vscode-notebook-cell:/c%3A/Users/annan/repos/AnnaBergknutGit/BTH/Till%C3%A4mpadAI/Task4.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> from sklearn import linear_model
#       <a href='vscode-notebook-cell:/c%3A/Users/annan/repos/AnnaBergknutGit/BTH/Till%C3%A4mpadAI/Task4.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> from sklearn.preprocessing import PolynomialFeatures
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
x_data = np.linspace(-0.5, 0.5, 200)[:, np.newaxis]
noise = np.random.normal(0, 0.02, x_data.shape)
y_data = np.square(x_data) + noise

# %%
model = linear_model.LinearRegression()

model.fit(x_data, y_data)
y_pred = model.predict(x_data)

# %%
plt.grid()
plt.scatter(x_data, y_data, c='b', label='Actual Data')
plt.plot(x_data, y_pred, c='r', label='linear Line')
plt.xlabel('X Data')
plt.ylabel('Y Data')
plt.legend()
plt.show()

# %%
mean_squared_error(y_data, y_pred)
# Out:
# 0.005744433235303397

# %%
model = Pipeline([('poly', PolynomialFeatures(degree=3)),('linear', LinearRegression(fit_intercept=False))])
model.fit(x_data, y_data)
y_pred = model.predict(x_data)

# %%
plt.grid()
plt.scatter(x_data, y_data, c='b', label='Actual Data')
plt.plot(x_data, y_pred, c='r', label='Regression Line')
plt.xlabel('X Data')
plt.ylabel('Y Data')
plt.legend()
plt.show()

# %%
mean_squared_error(y_data, y_pred)
# Out:
# 0.0003915314516904976

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.2, random_state = 0)

model = MLPRegressor([6],max_iter = 1000)
model.fit(x_train, np.ravel(y_train))
y_pred = model.predict(x_test)

# %%
plt.grid()
plt.scatter(x_train, y_train, c='b', label='Actual Data')
plt.scatter(x_test, y_pred, c='r', label=' Line')
plt.xlabel('X Data')
plt.ylabel('Y Data')
plt.legend()
plt.show()

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 0.006980063443408904
